# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.optimize import curve_fit
import scipy.stats as stat
from scipy import asarray as ar,exp

#kb=1.38064852*10**(-23)
kb=1.38064852e-5 #nm2.kg/K.s2
T=300

Na=6.02214e23
def gaussian(x,a,b,c):
    func=a*exp(-(x-b)**2/(2*c**2))
    return(func)

# %%
#from scipy import asarray as ar,exp
data=pd.read_csv("angdist2_SNaSNaSNa.xvg", skiprows=13,delim_whitespace=True, names=["Angle","frequency"])

x= data['Angle']
y=data['frequency']

n = len(data["Angle"])+1                          #the number of data
x0 = sum((data["Angle"])*(data["frequency"]))                   #note this correction
sigma = sum(y*(x-x0)**2)        #note this correction
print('mean=  ',x0)
print('sigma= ',sigma)
def gaus(x,a,x0,sigma):
    return a*exp(-(x-x0)**2/(2*sigma**2))

popt,pcov = curve_fit(gaus,x,y,p0=[1,x0,sigma])

plt.plot(x,y,'b+:',label='data')
plt.plot(x,gaus(x,*popt),'ro:',label='fit')
plt.legend()
plt.xlabel('Angle of SNaSNaSNa')
plt.ylabel('Frequency')
plt.show()

y_fits=gaussian(x,popt[0],popt[1],popt[2])
std=np.std([x,y_fits])
kb=1.38064852*10**(-23)
T=300
force_const=kb*T*Na/((std**2))
print('force constant= ',force_const) #Angle
# Out:
# mean=   60.000113
# sigma=  3.08920500079
# force constant=  2.65226308794

# %%
data1=pd.read_csv("bonds2_NdNd.xvg", skiprows=13,delim_whitespace=True, names=["bond","frequency"])
#n = len(x)+1  
num=sum(data1['frequency'])
#the number of data
x= data1['bond']
y=data1['frequency']
#num=sum(data1['frequency'])
#n = len(x)+1                          #the number of data
x0 = sum((x)*(y/num))                  #note this correction
sigma = (sum(y*(x-x0)**2)/num)**0.5        #note this correction
print('mean=  ',x0)
print('sigma= ',sigma)
def gaus(x,a,x0,sigma):
    
    return(a*exp(-(x-x0)**2/(2*sigma**2)))

popt,pcov = curve_fit(gaus,x,y,p0=[1,x0,sigma])

plt.plot(x,y,'b+:',label='data')
plt.plot(x,gaus(x,*popt),'ro:',label='fit')
plt.legend()
plt.xlabel('bond of NdNd')
plt.ylabel('Frequency')
plt.show()

y_fits=gaussian(x,popt[0],popt[1],popt[2])
std=np.std([x,y_fits])
kb=1.38064852*10**(-23)
T=300
force_const=kb*T*Na/((std**2))
print('force constant= ',force_const) #Angle
# Out:
# mean=   0.298717877546
# sigma=  0.00528603441465
# force constant=  6.8932560528

# %%
data2=pd.read_csv("bonds2_SNaC5.xvg", skiprows=13,delim_whitespace=True, names=["bond","frequency"])
#plt.plot(data1["bond"],data1['frequency'])
#n = len(x)+1  
num=sum(data2['frequency'])
#the number of data
x= data2['bond']
y= data2['frequency']
#num=sum(data1['frequency'])
#n = len(x)+1                          #the number of data
x0 = sum((x)*(y/num))                  #note this correction
sigma = (sum(y*(x-x0)**2)/num)**0.5        #note this correction
print('mean=  ',x0)
print('sigma= ',sigma)
def gaus(x,a,x0,sigma):
    
    return(a*exp(-(x-x0)**2/(2*sigma**2)))

popt,pcov = curve_fit(gaus,x,y,p0=[1,x0,sigma])

plt.plot(x,y,'b+:',label='data')
plt.plot(x,gaus(x,*popt),'ro:',label='fit')
plt.legend()
plt.xlabel('bond of SNaC5')
plt.ylabel('Frequency')
plt.show()

y_fits=gaussian(x,popt[0],popt[1],popt[2])
std=np.std([x,y_fits])
kb=1.38064852*10**(-23)
T=300
force_const=kb*T*Na/((std**2))
print('force constant= ',force_const) #Angle
# Out:
# mean=   0.235186336046
# sigma=  0.00586581826063
# force constant=  7.49719082125

# %%
data2=pd.read_csv("bonds2_SNaSNa.xvg", skiprows=13,delim_whitespace=True, names=["bond","frequency"])
#plt.plot(data1["bond"],data1['frequency'])
#n = len(x)+1  
num=sum(data2['frequency'])
#the number of data
x= data2['bond']
y=data2['frequency']
#num=sum(data1['frequency'])
#n = len(x)+1                          #the number of data
x0 = sum((x)*(y/num))                  #note this correction
sigma = (sum(y*(x-x0)**2)/num)**0.5        #note this correction
print('mean=  ',x0)
print('sigma= ',sigma)
def gaus(x,a,x0,sigma):
    
    return(a*exp(-(x-x0)**2/(2*sigma**2)))

popt,pcov = curve_fit(gaus,x,y,p0=[1,x0,sigma])

plt.plot(x,y,'b+:',label='data')
plt.plot(x,gaus(x,*popt),'ro:',label='fit')
plt.legend()
plt.xlabel('bond of SNaSNa')
plt.ylabel('Frequency')
plt.show()

y_fits=gaussian(x,popt[0],popt[1],popt[2])
std=np.std([x,y_fits])
kb=1.38064852*10**(-23)
T=300
force_const=kb*T*Na/((std**2))
print('force constant= ',force_const) #Angle
# Out:
# mean=   0.196644911125
# sigma=  0.00392333120922
# force constant=  3.17719473963

# %%
data=pd.read_csv("dihdist2_SNaNdNdSNa.xvg", skiprows=13,delim_whitespace=True, names=["dihedral","frequency"])


x= data['dihedral']
y= data['frequency']

n = len(x)+1                          #the number of data
x0 = sum((x)*(y))                   #note this correction
sigma = sum(y*(x-x0)**2)        #note this correction
print('mean=  ',x0)
print('sigma= ',sigma)
def gaus(x,a,x0,sigma):
    return a*exp(-(x-x0)**2/(2*sigma**2))

popt,pcov = curve_fit(gaus,x,y,p0=[1,x0,sigma])

plt.plot(x,y,'b+:',label='data')
plt.plot(x,gaus(x,*popt),'ro:',label='fit')
plt.legend()
plt.xlabel('Dihedral of SNaNdNdSNa')
plt.ylabel('Frequency')
plt.show()

y_fits=gaussian(x,popt[0],popt[1],popt[2])
std=np.std([x,y_fits])
kb=1.38064852*10**(-23)
T=300
force_const=kb*T*Na/((std**2))
print('force constant= ',force_const) #Angle
# Out:
# mean=   -8.299118
# sigma=  40.1317852974
# force constant=  13.9949892682

# %%
data4=pd.read_csv("bonds2_NdSNa_interior1.xvg", skiprows=13,delim_whitespace=True, names=["bond","frequency"])

#n = len(x)+1  
num=sum(data4['frequency'])
#the number of data
x= data4['bond']
y=data4['frequency']
#num=sum(data1['frequency'])
#n = len(x)+1                          #the number of data
x0 = sum((x)*(y/num))                  #note this correction
sigma = (sum(y*(x-x0)**2)/num)**0.5        #note this correction
print('mean=  ',x0)
print('sigma= ',sigma)
def gaus(x,a,x0,sigma):
    
    return(a*exp(-(x-x0)**2/(2*sigma**2)))

popt,pcov = curve_fit(gaus,x,y,p0=[1,x0,sigma])

plt.plot(x,y,'b+:',label='data')
plt.plot(x,gaus(x,*popt),'ro:',label='fit')
plt.legend()
plt.xlabel('bond of NdSNa interior 1')
plt.ylabel('Frequency')
plt.show()

y_fits=gaussian(x,popt[0],popt[1],popt[2])
std=np.std([x,y_fits])
kb=1.38064852*10**(-23)
T=300
force_const=kb*T*Na/((std**2))
print('force constant= ',force_const) #Angle
# Out:
# mean=   0.236913783753
# sigma=  0.0037674446574
# force constant=  3.01599547677

# %%
data4=pd.read_csv("bonds2_NdSNa_interior2.xvg", skiprows=13,delim_whitespace=True, names=["bond","frequency"])

#n = len(x)+1  
num=sum(data4['frequency'])
#the number of data
x= data4['bond']
y=data4['frequency']
#num=sum(data1['frequency'])
#n = len(x)+1                          #the number of data
x0 = sum((x)*(y/num))                  #note this correction
sigma = (sum(y*(x-x0)**2)/num)**0.5        #note this correction
print('mean=  ',x0)
print('sigma= ',sigma)
def gaus(x,a,x0,sigma):
    
    return(a*exp(-(x-x0)**2/(2*sigma**2)))

popt,pcov = curve_fit(gaus,x,y,p0=[1,x0,sigma])

plt.plot(x,y,'b+:',label='data')
plt.plot(x,gaus(x,*popt),'ro:',label='fit')
plt.legend()
plt.xlabel('bond of NdSNa interior 1')
plt.ylabel('Frequency')
plt.show()

y_fits=gaussian(x,popt[0],popt[1],popt[2])
std=np.std([x,y_fits])
kb=1.38064852*10**(-23)
T=300
force_const=kb*T*Na/((std**2))
print('force constant= ',force_const) #Angle
print(np.mean([0.236913783753,0.219067838016]))
print(np.mean([3.01599547677]))
# Out:
# mean=   0.219067838016
# sigma=  0.0042857819147
# force constant=  3.86324841683
# 0.227990810885

# %%
data4=pd.read_csv("bonds2_NdSNa_exterior.xvg", skiprows=13,delim_whitespace=True, names=["bond","frequency"])

#n = len(x)+1  
num=sum(data4['frequency'])
#the number of data
x= data4['bond']
y=data4['frequency']
#num=sum(data1['frequency'])
#n = len(x)+1                          #the number of data
x0 = sum((x)*(y/num))                  #note this correction
sigma = (sum(y*(x-x0)**2)/num)**0.5        #note this correction
print('mean=  ',x0)
print('sigma= ',sigma)
def gaus(x,a,x0,sigma):
    
    return(a*exp(-(x-x0)**2/(2*sigma**2)))

popt,pcov = curve_fit(gaus,x,y,p0=[1,x0,sigma])

plt.plot(x,y,'b+:',label='data')
plt.plot(x,gaus(x,*popt),'ro:',label='fit')
plt.legend()
plt.xlabel('bond of NdSNa exterior')
plt.ylabel('Frequency')
plt.show()

y_fits=gaussian(x,popt[0],popt[1],popt[2])
std=np.std([x,y_fits])
kb=1.38064852*10**(-23)
T=300
force_const=kb*T*Na/((std**2))
print('force constant= ',force_const) #Angle
# Out:
# mean=   0.17555160086
# sigma=  0.00476365774046
# force constant=  5.01166147725

# %%
data1=pd.read_csv("bonds2_SNbSNa.xvg", skiprows=13,delim_whitespace=True, names=["bond","frequency"])
#n = len(x)+1  
num=sum(data1['frequency'])
#the number of data
x= data1['bond']
y=data1['frequency']
#num=sum(data1['frequency'])
#n = len(x)+1                          #the number of data
x0 = sum((x)*(y/num))                  #note this correction
sigma = (sum(y*(x-x0)**2)/num)**0.5        #note this correction
print('mean=  ',x0)
print('sigma= ',sigma)
def gaus(x,a,x0,sigma):
    
    return(a*exp(-(x-x0)**2/(2*sigma**2)))

popt,pcov = curve_fit(gaus,x,y,p0=[1,x0,sigma])

plt.plot(x,y,'b+:',label='data')
plt.plot(x,gaus(x,*popt),'ro:',label='fit')
plt.legend()
plt.xlabel('bond of SNbSNa')
plt.ylabel('Frequency')
plt.show()

y_fits=gaussian(x,popt[0],popt[1],popt[2])
std=np.std([x,y_fits])
kb=1.38064852*10**(-23)
T=300
force_const=kb*T*Na/((std**2))
print('force constant= ',force_const) #Angle
# Out:
# mean=   0.197430403974
# sigma=  0.00413806219224
# force constant=  3.45892033597

# %%
#from scipy import asarray as ar,exp
data=pd.read_csv("angdist2_SNaSNbSNa.xvg", skiprows=13,delim_whitespace=True, names=["Angle","frequency"])

x= data['Angle']
y=data['frequency']

n = len(data["Angle"])+1                          #the number of data
x0 = sum((data["Angle"])*(data["frequency"]))                   #note this correction
sigma = sum(y*(x-x0)**2)        #note this correction
print('mean=  ',x0)
print('sigma= ',sigma)
def gaus(x,a,x0,sigma):
    return a*exp(-(x-x0)**2/(2*sigma**2))

popt,pcov = curve_fit(gaus,x,y,p0=[1,x0,sigma])

plt.plot(x,y,'b+:',label='data')
plt.plot(x,gaus(x,*popt),'ro:',label='fit')
plt.legend()
plt.xlabel('Angle of SNaSNbSNa')
plt.ylabel('Frequency')
plt.show()

y_fits=gaussian(x,popt[0],popt[1],popt[2])
std=np.std([x,y_fits])
kb=1.38064852*10**(-23)
T=300
force_const=kb*T*Na/((std**2))
print('force constant= ',force_const) #Angle
# Out:
# mean=   59.193121
# sigma=  1.39867693051
# force constant=  2.79925867272

# %%
#from scipy import asarray as ar,exp
data=pd.read_csv("angdist2_SNbSNaSNa.xvg", skiprows=13,delim_whitespace=True, names=["Angle","frequency"])

x= data['Angle']
y=data['frequency']

n = len(data["Angle"])+1                          #the number of data
x0 = sum((data["Angle"])*(data["frequency"]))                   #note this correction
sigma = sum(y*(x-x0)**2)        #note this correction
print('mean=  ',x0)
print('sigma= ',sigma)
def gaus(x,a,x0,sigma):
    return a*exp(-(x-x0)**2/(2*sigma**2))

popt,pcov = curve_fit(gaus,x,y,p0=[1,x0,sigma])

plt.plot(x,y,'b+:',label='data')
plt.plot(x,gaus(x,*popt),'ro:',label='fit')
plt.legend()
plt.xlabel('Angle of SNbSNaSNa')
plt.ylabel('Frequency')
plt.show()

y_fits=gaussian(x,popt[0],popt[1],popt[2])
std=np.std([x,y_fits])
kb=1.38064852*10**(-23)
T=300
force_const=kb*T*Na/((std**2))
print('force constant= ',force_const) #Angle
# Out:
# mean=   60.403623
# sigma=  3.44598807154
# force constant=  2.65240434421
